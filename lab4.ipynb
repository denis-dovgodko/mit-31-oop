# %% [markdown]
# Лабораторна 4. Метакласи і метапрограмування

# %%
from test_classes import Test, Test2

# %%
test = Test()
test2 = Test2()
print(test.compute(2, 3))
print(test.compute(2, 3))
print(test.compute(2, 3))
print(test.__dict__)

print(test.compute2(2, 3))
print(test2.compute(2, 3))
print(test.compute(y=5, x=4))
print(test.compute(x=4, y=5))
# Out:
# x: 2, y: 3. Calculating x+y ...
# 5
# 5
# 5
# {'_cache': {((2, 3), frozenset()): 5}}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 8
#       5 print(test.compute(2, 3))
#       6 print(test.__dict__)
# ----> 8 print(test.compute2(2, 3))
#       9 print(test2.compute(2, 3))
#      10 print(test.compute(y=5, x=4))
#
# AttributeError: 'Test' object has no attribute 'compute2'
